# %% [markdown]
# For this task, you should use the dataset from the first homework.
#
# Your dataset must contain at least 1000 descriptors, excluding the target ("raw_value"), and all the data cleansing steps must have been completed.
#
# Your task:
#
# 1. Choose one clustering algorithm suitable for your data and motivate your choice. Apply it, visualize and interpret your results.
#
# 2. Apply automated feature engineering algorithms to your data. Select the most relevant features using common sense and domain knowledge, and motivate your choice.
#
# 3. Implement automated feature selection in the context of a machine learning problem of your choice. You are expected to use molecular descriptors as feature vectors and any molecular property as a target variable. Visualize and interpret your results on selected features and their importance.
#
# Complete all the steps of the assignment in a Jupyter Notebook (one per team).
# Upload the finalized Jupyter Notebook to the Google Drive of the course or to GitHub.

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import requests
import re
from statistics import mean, median
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import requests
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('df_final_with_descriptors.csv', low_memory=False, index_col = 'Unnamed: 0')

# %%
df
# Out:
#            Date                                            Journal  \
# 0     5/25/2011                Physical Chemistry Chemical Physics
# 1     9/13/1999                    Journal of Alloys and Compounds
# 2      3/4/1999  Colloids and Surfaces A: Physicochemical and E...
# 3      8/5/2004               Materials Science and Engineering: B
# 4     12/1/2016                                              Optik
# ...         ...                                                ...
# 2968  7/30/2011                                 Thermochimica Acta
# 2969   6/9/2015                                           RSC Adv.
# 2970  6/17/2015                            Phys. Chem. Chem. Phys.
# 2971  4/13/2017                           Vibrational Spectroscopy
# 2972  9/12/2001  Journal of Photochemistry and Photobiology A: ...
#
#                                                   Title             Name  \
# 0     Kirkwood correlation factors in liquid mixture...         Triglyme
# 1     GROWTHOPTICALPROPERTIESREDOPEDBULKFIBERSINGLEC...             YVO4
# 2     ADSORPTIONOILSURFACTANTMONOLAYERSSTRUCTUREMIXE...          Toluene
# 3     Fabrication of PECVD-silicon oxynitride-based ...  silicon dioxide
# 4     OPTIMIZATIONENHANCEMENTLIQUIDANALYTESENSINGPER...          Benzyne
# ...                                                 ...              ...
# 2968  THERMOPHYSICALSTUDYNHEXANENHEPTANE1CHLOROPROPA...        n-Heptane
# 2969  Semitransparent polymer-based solar cells via ...             TiO2
# 2970  Transformation of photophysical properties fro...      1,4-Dioxane
# 2971  IMPROVEMENTSTIO2CATALYZEDAGNPSBASEDSERSSUBSTRA...             TiO2
# 2972  PHOTOPHYSICALPROPERTIES25DIPHENYLTHIAZOLO54DTH...       Chloroform
#
#       wavelength_added        RI                        DOI_alt  \
# 0                589.0  1.421120             10.1039/C1CP20142E
# 1                589.0  2.168000  10.1016/S0925-8388(98)00420-4
# 2                589.0  1.494000  10.1016/S0927-7757(98)00782-1
# 3                589.0  1.460000     10.1016/j.mseb.2004.05.037
# 4                589.0  1.354000    10.1016/j.ijleo.2016.11.171
# ...                ...       ...                            ...
# 2968             589.0  1.390333      10.1016/j.tca.2011.07.023
# 2969              26.0  1.640000             10.1039/C5RA05762K
# 2970             589.0  1.420300             10.1039/C5CP02762D
# 2971             589.0  1.630000  10.1016/j.vibspec.2017.03.005
# 2972             357.2  1.447600  10.1016/S1010-6030(01)00520-2
#
#                                  SMILES  Method_ord  Publisher_ord  ...  \
# 0                          COCCOCCOCCOC           1              1  ...
# 1     [O-2].[O-2].[O-2].[O-2].[V].[Y+3]           1              0  ...
# 2                          CC1=CC=CC=C1           1              0  ...
# 3                              O=[Si]=O           3              0  ...
# 4                           C1=CC#CC=C1           2              0  ...
# ...                                 ...         ...            ...  ...
# 2968                            CCCCCCC           0              0  ...
# 2969                           O=[Ti]=O           0              1  ...
# 2970                           C1COCCO1           0              1  ...
# 2971                           O=[Ti]=O           2              0  ...
# 2972                        C(Cl)(Cl)Cl           0              0  ...
#
#            P1s       P2s       E1s       E2s       E3s         Ts         As  \
# 0     0.946528  0.031934  0.549275  0.526084  0.492699  19.717294  19.944032
# 1          NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2     0.645928  0.332469  0.550605  0.453388  0.125625   5.009615   5.919881
# 3          NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 4     0.560564  0.426347  0.464710  0.524683  0.276782   3.839450   3.713540
# ...        ...       ...       ...       ...       ...        ...        ...
# 2968  0.856853  0.086350  0.562047  0.557496  0.590060   8.745269   9.755805
# 2969       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2970  0.552766  0.330474  0.649745  0.843263  0.503156   4.024970   4.630103
# 2971       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2972  0.410138  0.388439  0.405419  0.394998  0.370627   2.166662   1.502992
#
#              Vs        Ks        Ds
# 0     44.651635  0.919793  1.568058
# 1           NaN       NaN       NaN
# 2     11.512744  0.468892  1.129618
# 3           NaN       NaN       NaN
# 4      7.730048  0.480366  1.266175
# ...         ...       ...       ...
# 2968  21.311787  0.785279  1.709602
# 2969        NaN       NaN       NaN
# 2970  10.045862  0.329148  1.996164
# 2971        NaN       NaN       NaN
# 2972   3.996043  0.197865  1.171044
#
# [2973 rows x 1925 columns]

# %% [markdown]
# # Clustering

# %% [markdown]
# # Feature engineering

# %% [markdown]
# # Feature importance
